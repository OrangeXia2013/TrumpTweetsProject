# %% [markdown]
# # Import packages

# %%
import os
import re
import time
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# # Update local stock list

# %%
def update_stocklist_data():
    ''' Functions for update stocklist data
    Source: www.nasdaq.com
    '''
    # create stock_list data folder
    folder = os.getcwd() + '\\stock_list\\'
    if not os.path.exists(folder):
        os.makedirs(folder)

    # soure url
    url = 'https://www.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=%s&render=download'

    # available exhanges
    exchange = ['nasdaq', 'nyse', 'amex']

    for exchg in exchange:
        resp = requests.get(url%exchg)
        with open(folder + '%s.xlsx'%exchg, 'wb') as output:
            output.write(resp.content)
    pass

# update stock_list
update_stocklist_data()

# %% [markdown]
# # Read local stock list and clean data

# %%
# data folder
folder = os.getcwd() + '\\stock_list\\'

# file names
files = os.listdir( folder )

files
# Out:
# ['amex.xls', 'nasdaq.xls', 'nyse.xls']

# %%
stolis_df_list = []
for f in files:
    df = pd.read_csv( folder + f )
    stolis_df_list.append(df)
    print(f.upper(),df.shape, '\n==================================================\n',
          df[['Name']].head() )
    print('==================================================\n')
# Out:
# AMEX.XLS (309, 9)
# ==================================================
#                                                  Name
# 0                            22nd Century Group, Inc
# 1              Aberdeen Asia-Pacific Income Fund Inc
# 2                 Aberdeen Australia Equity Fund Inc
# 3  Aberdeen Emerging Markets Equity Income Fund, ...
# 4                  Aberdeen Global Income Fund, Inc.
# ==================================================
#
# NASDAQ.XLS (3450, 9)
# ==================================================
#                                       Name
# 0                               111, Inc.
# 1  1347 Property Insurance Holdings, Inc.
# 2  1347 Property Insurance Holdings, Inc.
# 3                180 Degree Capital Corp.
# 4                 1-800 FLOWERS.COM, Inc.
# ==================================================
#
# NYSE.XLS (3104, 9)
# ==================================================
#                       Name
# 0  3D Systems Corporation
# 1              3M Company
# 2         500.com Limited
# 3             58.com Inc.
# 4                 8x8 Inc
# ==================================================

# %%
# concatenate companies from three exhanges
stolis_df_ = pd.concat(stolis_df_list, axis = 0)

# drop dupplicated company names
stolis_df = stolis_df_.drop_duplicates(['Name']).reset_index(drop = True)

print('Total %s companies, unique %s companies.' % (stolis_df_.shape[0], stolis_df.shape[0]))
# Out:
# Total 6863 companies, unique 5770 companies.

# %% [markdown]
# # Prepare tweets data

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Data handle.ipynb',
#  'data.csv',
#  'data.xlsx',
#  'event_selecting_logic.md',
#  'nasdaq.xls',
#  'stock_list',
#  'tweets.txt',
#  'tweets_data.csv',
#  'tweets_data.xlsx',
#  'word frequency.csv',
#  'words_database.xlsx',
#  'word_list.csv',
#  'word_lst.csv',
#  '~$words_database.xlsx']

# %%
# filename
filename = 'tweets.txt'

# read txt file
file = open(filename).read()

# convert json format to dataframe
data = pd.DataFrame(eval(file.replace('false', 'False').replace('true', 'True')))

# store tweets in excel
data.to_excel('data.xlsx')

# %%
def is_in(string, str_lst = ['data'], lower = True):
    ''' Detect whether words in *str_lst* exist in *string* or not.
    Input:
    
    -- string: string for examing
               str format
               
    -- str_lst: a list of key words
                list of str
                default is *[' data ']*
    
    -- lower: determine whether capital letter is ignored or not, 
              True -> ignore capital letters, transform all string to lower case;
              Fasle -> capital letters can't be ignored, both in *string* and *str_lst*.
    
    Output:
    
    -- if any key words is detedted:
           return a string with all key words emphathized
           
       else:
           return numpy.nan
    '''
    string = ' %s '%string
    if lower:
        
        def my_lable(string, str_lst = str_lst):
            for s in str_lst:
                string = re.sub(r'(?<=\W)%s(?=\W)'%s.lower(), ' {%s} '%s.upper(), string )
            return string

        string = string.lower()

        if any( [(i.lower() in string) for i in str_lst ] ):
            return my_lable(string)

        else:
            return np.nan
        
    else:
        
        def my_lable(string, str_lst = str_lst):
            for s in str_lst:
                string = re.sub(r'(?<=\W)%s(?=\W)'%s, ' {%s} '%s.upper(), string )
            return string

        string = string

        if any( [(i in string) for i in str_lst ] ):
            return my_lable(string)

        else:
            return np.nan

# %%
def count_pattern(string, dict_):
    pattern = re.compile(r'{ (.*?) }', re.S)
    items = re.findall(pattern, string)
    for i in items:
        try:
            dict_[i] += 1.
        except:
            dict_[i] = 1.
    return dict_

# %%
data.columns
# Out:
# Index(['created_at', 'favorite_count', 'id_str', 'is_retweet', 'retweet_count',
#        'source', 'text'],
#       dtype='object')

# %%
data['created_at'] = pd.to_datetime( data['created_at'])

# %% [markdown]
# # Search STR_list

# %%
def search_str_lst(str_lst):
    assert type(str_lst) == list, 'Type of str_lst must be list!'
    i = 1
    dict_ = {}
    v_lst = data['text'].apply(is_in, str_lst= str_lst).dropna().values
    for v in v_lst:
        dict_ = count_pattern(v, dict_)
        print(v)
        print('================================================%s/%s\n'%( i, len(v_lst) ))
        i += 1
    pass

# %%
search_str_lst(['data'])
# Out:
#  “outrageous, it’s the adam schiff problem. people abusing the access to classified  {DATA}  to then go out in public and make allegations that didn’t prove to be true. you look at a decision to essentially investigate a political rival. who made it?” james freeman, @wsj
# ================================================1/3
#
#  cbs reports that in the roger stone indictment,  {DATA}  was “released during the 2016 election to damage hillary clinton.” oh really! what about the fake and unverified “dossier,” a total phony conjob, that was paid for by crooked hillary to damage me and the trump campaign? what...
# ================================================2/3
#
#  many mostly democrat states refused to hand over  {DATA}  from the 2016 election to the commission on voter fraud. they fought hard that the commission not see their records or methods because they know that many people are voting illegally. system is rigged, must go to voter i.d.
# ================================================3/3

# %%
drop_lst = '''Company,Laboratories,Inc,plc,corp,group,equities,pharmaceutical,technology,plc,coporation,co,
networks,green,texas,holdings,Inc,properties,holdings,energy,communications,limited,solutions,resources,brands,
hunt,companies,health,restrants,services,chemical,int,l,arts,resources,Holdings,Holding,Inc,Cos,Ltd,Corp,Co,plc,
red,space,under,Cos,Group,properties,Corporation,Incorporated,tree,business,city,Residential,Company,TOTAL,one,
line,gas,network,black,federal,union ,best,air,water,U,S,Trust,Arts,Communications,Chemical,Lifesciences,
Technologies,Systems,General,First,Street,Southern,Networks,Realty,Service,Class,A,Materials,Class,Cruise,Line,
Services,Financial,Resources,NATIONAL ,Foods,Scientific,Beauty,Realty,Communications,com,Automotive,Stores,
Technologies,International,WEST ,Markets,Machines,Sciences,Exchange,Tool,Works,Dynamics,Bank,Investment,limited,
Laboratories,NEWS ,technology,Resources,Resorts,equities,energy,health,Parts,brands,and,a,at,on,take,of,Church,
system,new,UNITED,Republic,OIL ,real,york,the,AMERICAN, america,state,C,Data,SECURITY ,companies,restrants
'''.replace(' ', '').replace('\n', '').lower().split(',')

# %%
drop_set = {*drop_lst}

# %% [markdown]
# # Company name search

# %%
# split stock names
name_df = stolis_df[['Name']].copy()

name_df['words'] = pd.DataFrame( name_df['Name'].apply(lambda x: \
                                                        re.findall(r'(\w+)', x) ) )
name_df.head()
# Out:
#                                                 Name  \
# 0                            22nd Century Group, Inc
# 1              Aberdeen Asia-Pacific Income Fund Inc
# 2                 Aberdeen Australia Equity Fund Inc
# 3  Aberdeen Emerging Markets Equity Income Fund, ...
# 4                  Aberdeen Global Income Fund, Inc.
#
#                                                words
# 0                        [22nd, Century, Group, Inc]
# 1       [Aberdeen, Asia, Pacific, Income, Fund, Inc]
# 2           [Aberdeen, Australia, Equity, Fund, Inc]
# 3  [Aberdeen, Emerging, Markets, Equity, Income, ...
# 4              [Aberdeen, Global, Income, Fund, Inc]

# %%
def knock_out(lst, drop_lst = drop_set):
    ''' Knock out words in drop_set
    '''
    lst_ = []
    for i in lst:
        # if in drop_lst or length < 2, drop it
        if i.lower() in drop_lst or len(i)< 2:
            pass
        else:
            lst_.append(i)
            
    if len(lst_) > 0:
        return lst_
    
    else:
        return np.nan

name_df['dropped'] = name_df['words'].apply(knock_out)

# %%
dropped_companies = name_df[name_df['dropped'] != name_df['dropped']]
print('%s companies are dropped out from stock list.'%dropped_companies.shape[0])
# Out:
# 58 companies are dropped out from stock list.

# %%
name_df = name_df.dropna()
print('%s companies are kept after dropping out.'%name_df.shape[0])
# Out:
# 5712 companies are kept after dropping out.

# %% [markdown]
# # Re-arrange key-words and companies

# %%
name_df.head()
# Out:
#                                                 Name  \
# 0                            22nd Century Group, Inc
# 1              Aberdeen Asia-Pacific Income Fund Inc
# 2                 Aberdeen Australia Equity Fund Inc
# 3  Aberdeen Emerging Markets Equity Income Fund, ...
# 4                  Aberdeen Global Income Fund, Inc.
#
#                                                words  \
# 0                        [22nd, Century, Group, Inc]
# 1       [Aberdeen, Asia, Pacific, Income, Fund, Inc]
# 2           [Aberdeen, Australia, Equity, Fund, Inc]
# 3  [Aberdeen, Emerging, Markets, Equity, Income, ...
# 4              [Aberdeen, Global, Income, Fund, Inc]
#
#                                       dropped
# 0                             [22nd, Century]
# 1     [Aberdeen, Asia, Pacific, Income, Fund]
# 2         [Aberdeen, Australia, Equity, Fund]
# 3  [Aberdeen, Emerging, Equity, Income, Fund]
# 4            [Aberdeen, Global, Income, Fund]

# %%
# Save all words

# %%
def save_words_dict_data():
    words_dict = {}
    for i in range( name_df.shape[0] ):
        words = name_df['dropped'].values[i]
        comp  = name_df['Name'   ].values[i]

        for w in words:
            try:
                words_dict[w] += '%s, '%comp
            except:
                words_dict[w] = ''
                words_dict[w] += '%s, '%comp
    pd.DataFrame(words_dict, index = [0]).T.to_excel('words_database.xlsx')
    pass
save_words_dict_data()

# %%
words_dict = {}
for i in range( name_df.shape[0] ):
    words = name_df['dropped'].values[i]
    comp  = name_df['Name'   ].values[i]
    
    for w in words:
        try:
            words_dict[w] += ['%s, '%comp]
        except:
            words_dict[w] = []
            words_dict[w] += ['%s, '%comp]

# %%
words_dict
# Out:
# {'22nd': ['22nd Century Group, Inc, '],
#  'Century': ['22nd Century Group, Inc, ',
#   'Century Aluminum Company, ',
#   'Century Bancorp, Inc., ',
#   'Century Casinos, Inc., ',
#   'Century Communities, Inc., '],
#  'Aberdeen': ['Aberdeen Asia-Pacific Income Fund Inc, ',
#   'Aberdeen Australia Equity Fund Inc, ',
#   'Aberdeen Emerging Markets Equity Income Fund, Inc., ',
#   'Aberdeen Global Income Fund, Inc., ',
#   'Aberdeen Global Dynamic Dividend Fund, ',
#   'Aberdeen Global Premier Properties Fund, ',
#   'Aberdeen Income Credit Strategies Fund, ',
#   'Aberdeen Japan Equity Fund, Inc. , ',
#   'Aberdeen Total Dynamic Dividend Fund, ',
#   'First Trust/Aberdeen Emerging Opportunity Fund, ',
#   'First Trust/Aberdeen Global Opportunity Income Fund, '],
#  'Asia': ['Aberdeen Asia-Pacific Income Fund Inc, ',
#   'Asia Pacific Wire & Cable Corporation Limited, ',
#   'First Trust Asia Pacific Ex-Japan AlphaDEX Fund, ',
#   'First Trust RiverFront Dynamic Asia Pacific ETF, ',
#   'iClick Interactive Asia Group Limited, ',
#   'Invesco BLDRS Asia 50 ADR Index Fund, ',
#   'iShares Asia 50 ETF, ',
#   'iShares MSCI All Country Asia ex Japan Index Fund, ',
#   'iShares MSCI Emerging Markets Asia ETF, ',
#   'Voya Asia Pacific High Dividend Equity Income Fund, '],
#  'Pacific': ['Aberdeen Asia-Pacific Income Fund Inc, ',
#   'Pacific Gas & Electric Co., ',
#   'Asia Pacific Wire & Cable Corporation Limited, ',
#   'First Trust Asia Pacific Ex-Japan AlphaDEX Fund, ',
#   'First Trust RiverFront Dynamic Asia Pacific ETF, ',
#   'JAKKS Pacific, Inc., ',
#   'Pacific Biosciences of California, Inc., ',
#   'Pacific City Financial Corporation, ',
#   'Pacific Ethanol, Inc., ',
#   'Pacific Mercantile Bancorp, ',
#   'Pacific Premier Bancorp Inc, ',
#   'Canadian Pacific Railway Limited, ',
#   'Hudson Pacific Properties, Inc., ',
#   'Louisiana-Pacific Corporation, ',
#   'Pacific Coast Oil Trust, ',
#   'Pacific Drilling S.A., ',
#   'Par Pacific Holdings, Inc., ',
#   'Texas Pacific Land Trust, ',
#   'Union Pacific Corporation, ',
#   'Voya Asia Pacific High Dividend Equity Income Fund, '],
#  'Income': ['Aberdeen Asia-Pacific Income Fund Inc, ',
#   'Aberdeen Emerging Markets Equity Income Fund, Inc., ',
#   'Aberdeen Global Income Fund, Inc., ',
#   'Clough Global Dividend and Income Fund, ',
#   'Credit Suisse Asset Management Income Fund, Inc., ',
#   'Delaware Investments Colorado Municipal Income Fund, Inc, ',
#   'Delaware Investments Florida Insured Municipal Income Fund, ',
#   'Delaware Investments Minnesota Municipal Income Fund II, Inc., ',
#   'Dreyfus Municipal Income, Inc., ',
#   'Eaton Vance California Municipal Income Trust, ',
#   'Eaton Vance Limited Duration Income Fund, ',
#   'Eaton Vance New York Municipal Income Trust, ',
#   'Ellsworth Growth and Income Fund Ltd., ',
#   'First Trust Energy Income and Growth Fund, ',
#   'Franklin Limited Duration Income Trust, ',
#   'GAMCO Global Gold, Natural Reources & Income Trust , ',
#   'Income Opportunity Realty Investors, Inc., ',
#   'Invesco Advantage Municipal Income Trust II, ',
#   'Neuberger Berman MLP Income Fund Inc., ',
#   'Neuberger Berman Real Estate Securities Income Fund, Inc., ',
#   'Pioneer Diversified High Income Trust, ',
#   'Reaves Utility Income Fund, ',
#   'RMR Real Estate Income Fund, ',
#   'The Gabelli Global Utility and Income Trust, ',
#   'Wells Fargo Income Opportunities Fund, ',
#   'Wells Fargo Multi-Sector Income Fund, ',
#   'Wells Fargo Utilities and High Income Fund, ',
#   'Calamos Convertible and High Income Fund, ',
#   'Calamos Convertible Opportunities and Income Fund, ',
#   'Calamos Dynamic Convertible & Income Fund, ',
#   'Calamos Global Dynamic Income Fund, ',
#   'First Trust BuyWrite Income ETF, ',
#   'First Trust CEF Income Opportunity ETF, ',
#   'First Trust Hedged BuyWrite Income ETF, ',
#   'First Trust Indxx Global Natural Resources Income ETF, ',
#   'First Trust Multi-Asset Diversified Income Index Fund, ',
#   'First Trust Municipal CEF Income Opportunity ETF, ',
#   'First Trust Municipal High Income ETF, ',
#   'First Trust Strategic Income ETF, ',
#   'First Trust TCW Opportunistic Fixed Income ETF, ',
#   'Global X YieldCo & Renewable Energy Income ETF, ',
#   'Invesco DWA Tactical Multi-Asset Income ETF, ',
#   'iShares Preferred and Income Securities ETF, ',
#   'Oaktree Strategic Income Corporation, ',
#   'Office Properties Income Trust, ',
#   'SPDR Dorsey Wright Fixed Income Allocation ETF, ',
#   'VictoryShares US EQ Income Enhanced Volatility Wtd ETF, ',
#   'Western Asset Short Duration Income ETF, ',
#   'Aberdeen Income Credit Strategies Fund, ',
#   'Advent Claymore Convertible Securities and Income Fund, ',
#   'Alliance California Municipal Income Fund Inc, ',
#   'Alliance National Municipal Income Fund Inc, ',
#   'AllianzGI Convertible & Income 2024 Target Term Fund, ',
#   'AllianzGI Convertible & Income Fund, ',
#   'AllianzGI Convertible & Income Fund II, ',
#   'AllianzGI Diversified Income & Convertible Fund, ',
#   'AllianzGI Equity & Convertible Income Fund, ',
#   'Apollo Tactical Income Fund Inc., ',
#   'BlackRock 2022 Global Income Opportunity Trust, ',
#   'BlackRock California Municipal Income Trust, ',
#   'Blackrock Capital and Income Strategies Fund Inc, ',
#   'BlackRock Credit Allocation Income Trust, ',
#   'Blackrock Floating Rate Income Strategies Fund Inc, ',
#   'BlackRock Income Investment Quality Trust, ',
#   'BlackRock Income Trust Inc. (The), ',
#   'BlackRock Multi-Sector Income Trust, ',
#   'BlackRock Municipal Income Investment Trust, ',
#   'Blackrock Municipal Income Quality Trust, ',
#   'BlackRock Municipal Income Trust, ',
#   'BlackRock Municipal Income Trust II, ',
#   'Blackrock New York Municipal Income Quality Trust, ',
#   'BlackRock New York Municipal Income Trust II, ',
#   'Blackstone GSO Long Short Credit Income Fund, ',
#   'BrandywineGLOBAL Global Income Opportunities Fund , ',
#   'Brookfield Global Listed Infrastructure Income Fund, ',
#   'Brookfield Real Assets Income Fund Inc., ',
#   'CBRE Clarion Global Real Estate Income Fund, ',
#   'Cohen & Steers Global Income Builder, Inc., ',
#   'Cohen & Steers Limited Duration Preferred and Income Fund, Inc, ',
#   'Cohen & Steers MLP Income and Energy Opportunity Fund, Inc., ',
#   'Cohen & Steers Quality Income Realty Fund Inc, ',
#   'Cohen & Steers REIT and Preferred and Income Fund,, ',
#   'Cohen & Steers Select Preferred and Income Fund, Inc., ',
#   'Colonial High Income Municipal Trust, ',
#   'Colonial Intermediate High Income Fund, ',
#   'Colonial Municipal Income Trust, ',
#   'Cushing Energy Income Fund (The), ',
#   'Delaware Investments Dividend & Income Fund, Inc., ',
#   'Dividend and Income Fund, ',
#   'DoubleLine Income Solutions Fund, ',
#   'Duff & Phelps Global Utility Income Fund Inc., ',
#   'Duff & Phelps Utilities Income, Inc., ',
#   'Duff & Phelps Utilities Tax-Free Income, Inc., ',
#   'Eagle Growth and Income Opportunities Fund, ',
#   'Eaton Vance Enhance Equity Income Fund, ',
#   'Eaton Vance Enhanced Equity Income Fund II, ',
#   'Eaton Vance Floating Rate Income Trust, ',
#   'Eaton vance Floating-Rate Income Plus Fund, ',
#   'Eaton Vance High Income 2021 Target Term Trust, ',
#   'Eaton Vance Municipal Income 2028 Term Trust, ',
#   'Eaton Vance Municipal Income Trust, ',
#   'Eaton Vance Risk-Managed Diversified Equity Income Fund, ',
#   'Eaton Vance Senior Income Trust, ',
#   'Eaton Vance Short Diversified Income Fund, ',
#   'Eaton Vance Tax Advantaged Dividend Income Fund, ',
#   'Eaton Vance Tax-Advantaged Global Dividend Income Fund, ',
#   'Eaton Vance Tax-Managed Buy-Write Income Fund, ',
#   'Eaton Vance Tax-Managed Diversified Equity Income Fund, ',
#   'Eaton Vance Tax-Managed Global Diversified Equity Income Fund, ',
#   'Federated Premier Municipal Income Fund, ',
#   'First Trust Dynamic Europe Equity Income Fund, ',
#   'First Trust High Income Long Short Fund, ',
#   'First Trust Intermediate Duration Preferred & Income Fund, ',
#   'First Trust MLP and Energy Income Fund, ',
#   'First Trust Senior Floating Rate Income Fund II, ',
#   'First Trust/Aberdeen Global Opportunity Income Fund, ',
#   'Flaherty & Crumrine Dynamic Preferred and Income Fund Inc., ',
#   'Flaherty & Crumrine Preferred Income Fund Incorporated, ',
#   'Flaherty & Crumrine Preferred Income Opportunity Fund Inc, ',
#   'Flaherty & Crumrine Preferred Securities Income Fund Inc, ',
#   'Gabelli Convertible and Income Securities Fund, Inc. (The), ',
#   'GAMCO Natural Resources, Gold & Income Tust , ',
#   'Goldman Sachs MLP Income Opportunities Fund, ',
#   'Guggenheim Enhanced Equity Income Fund, ',
#   'High Income Securities Fund, ',
#   'Insight Select Income Fund, ',
#   'Invesco California Value Municipal Income Trust, ',
#   'Invesco High Income 2023 Target Term Fund, ',
#   'Invesco High Income 2024 Target Term Fund, ',
#   'Aberdeen Emerging Markets Equity Income Fund, Inc., ',
#   'Aberdeen Global Income Fund, Inc., ',
#   'Bancroft Fund Limited, ',
#   'Clough Global Dividend and Income Fund, ',
#   'Clough Global Equity Fund, ',
#   'Clough Global Opportunities Fund, ',
#   'Cornerstone Strategic Return Fund, Inc. (The), ',
#   'Cornerstone Strategic Value Fund, Inc., ',
#   'Credit Suisse Asset Management Income Fund, Inc., ',
#   'Credit Suisse High Yield Bond Fund, ',
#   'Delaware Investments Colorado Municipal Income Fund, Inc, ',
#   'Delaware Investments Florida Insured Municipal Income Fund, ',
#   'Delaware Investments Minnesota Municipal Income Fund II, Inc., ',
#   'Eagle Capital Growth Fund, Inc., ',
#   'Eaton Vance California Municipal Bond Fund, ',
#   'Eaton Vance Limited Duration Income Fund, ',
#   'Eaton Vance Municipal Bond Fund, ',
#   'Eaton Vance New York Municipal Bond Fund, ',
#   'Ellsworth Growth and Income Fund Ltd., ',
#   'First Trust Energy Income and Growth Fund, ',
#   'Neuberger Berman California Municipal Fund Inc, ',
#   'Neuberger Berman High Yield Strategies Fund, ',
#   'Neuberger Berman MLP Income Fund Inc., ',
#   'Neuberger Berman Municipal Fund Inc., ',
#   'Neuberger Berman New York Municipal Fund Inc., ',
#   'Neuberger Berman Real Estate Securities Income Fund, Inc., ',
#   'Reaves Utility Income Fund, ',
#   'RENN Fund, Inc., ',
#   'RMR Real Estate Income Fund, ',
#   'Wells Fargo Income Opportunities Fund, ',
#   'Wells Fargo Multi-Sector Income Fund, ',
#   'Wells Fargo Utilities and High Income Fund, ',
#   'Calamos Convertible and High Income Fund, ',
#   'Calamos Convertible Opportunities and Income Fund, ',
#   'Calamos Dynamic Convertible & Income Fund, ',
#   'Calamos Global Dynamic Income Fund, ',
#   'Calamos Global Total Return Fund, ',
#   'Calamos Strategic Total Return Fund, ',
#   'ETF Series Solutions Trust Vident Core U.S. Bond Strategy Fund, ',
#   'ETF Series Solutions Trust Vident International Equity Fund, ',
#   'First Trust Asia Pacific Ex-Japan AlphaDEX Fund, ',
#   'First Trust BICK Index Fund, ',
#   'First Trust Brazil AlphaDEX Fund, ',
#   'First Trust Canada AlphaDEX Fund, ',
#   'First Trust China AlphaDEX Fund, ',
#   'First Trust Developed Markets Ex-US AlphaDEX Fund, ',
#   'First Trust Developed Markets ex-US Small Cap AlphaDEX Fund, ',
#   'First Trust Emerging Markets AlphaDEX Fund, ',
#   'First Trust Emerging Markets Small Cap AlphaDEX Fund, ',
#   'First Trust Europe AlphaDEX Fund, ',
#   'First Trust Germany AlphaDEX Fund, ',
#   'First Trust Global Tactical Commodity Strategy Fund, ',
#   'First Trust Hong Kong AlphaDEX Fund, ',
#   'First Trust Japan AlphaDEX Fund, ',
#   'First Trust Large Cap Core AlphaDEX Fund, ',
#   'First Trust Large Cap Growth AlphaDEX Fund, ',
#   'First Trust Large Cap Value AlphaDEX Fund, ',
#   'First Trust Latin America AlphaDEX Fund, ',
#   'First Trust Mega Cap AlphaDEX Fund, ',
#   'First Trust Mid Cap Core AlphaDEX Fund, ',
#   'First Trust Mid Cap Growth AlphaDEX Fund, ',
#   'First Trust Mid Cap Value AlphaDEX Fund, ',
#   'First Trust Multi Cap Growth AlphaDEX Fund, ',
#   'First Trust Multi Cap Value AlphaDEX Fund, ',
#   'First Trust Multi-Asset Diversified Income Index Fund, ',
#   'First Trust NASDAQ ABA Community Bank Index Fund, ',
#   'First Trust NASDAQ Clean Edge Green Energy Index Fund, ',
#   'First Trust NASDAQ Global Auto Index Fund, ',
#   'First Trust NASDAQ Smartphone Index Fund, ',
#   'First Trust NASDAQ Technology Dividend Index Fund, ',
#   'First Trust NASDAQ-100 Equal Weighted Index Fund, ',
#   'First Trust NASDAQ-100 Ex-Technology Sector Index Fund, ',
#   'First Trust NASDAQ-100- Technology Index Fund, ',
#   'First Trust Senior Loan Fund ETF, ',
#   'First Trust Small Cap Core AlphaDEX Fund, ',
#   'First Trust Small Cap Growth AlphaDEX Fund, ',
#   'First Trust Small Cap Value AlphaDEX Fund, ',
#   'First Trust South Korea AlphaDEX Fund, ',
#   'First Trust Switzerland AlphaDEX Fund, ',
#   'First Trust United Kingdom AlphaDEX Fund, ',
#   'Firsthand Technology Value Fund, Inc., ',
#   'FlexShares Credit-Scored US Corporate Bond Index Fund, ',
#   'FlexShares Credit-Scored US Long Corporate Bond Index Fund, ',
#   'FlexShares Disciplined Duration MBS Index Fund, ',
#   'FlexShares Real Assets Allocation Index Fund, ',
#   'FlexShares STOXX Global ESG Impact Index Fund, ',
#   'FlexShares STOXX US ESG Impact Index Fund, ',
#   'FlexShares US Quality Large Cap Index Fund, ',
#   'Invesco BLDRS Asia 50 ADR Index Fund, ',
#   'Invesco BLDRS Developed Markets 100 ADR Index Fund, ',
#   'Invesco BLDRS Emerging Markets 50 ADR Index Fund, ',
#   'Invesco BLDRS Europe Select ADR Index Fund, ',
#   'iShares FTSE EPRA/NAREIT Europe Index Fund, ',
#   'iShares FTSE EPRA/NAREIT Global Real Estate ex-U.S. Index Fund, ',
#   'iShares MSCI ACWI ex US Index Fund, ',
#   'iShares MSCI ACWI Index Fund, ',
#   'iShares MSCI All Country Asia ex Japan Index Fund, ',
#   'iShares MSCI Europe Financials Sector Index Fund, ',
#   'iShares Nasdaq Biotechnology Index Fund, ',
#   'iShares PHLX SOX Semiconductor Sector Index Fund, ',
#   'iShares S&P Emerging Markets Infrastructure Index Fund, ',
#   'iShares S&P Global Clean Energy Index Fund, ',
#   'iShares S&P Global Timber & Forestry Index Fund, ',
#   'iShares S&P India Nifty 50 Index Fund, ',
#   'Nuveen NASDAQ 100 Dynamic Overwrite Fund, ',
#   'The Herzfeld Caribbean Basin Fund, Inc., ',
#   'Vanguard Short-Term Inflation-Protected Securities Index Fund, ',
#   'WisdomTree Barclays Negative Duration U.S. Aggregate Bond Fund, ',
#   'WisdomTree China ex-State-Owned Enterprises Fund, ',
#   'WisdomTree Emerging Markets Consumer Growth Fund, ',
#   'WisdomTree Emerging Markets Corporate Bond Fund, ',
#   'WisdomTree Emerging Markets Quality Dividend Growth Fund, ',
#   'WisdomTree Germany Hedged Equity Fund, ',
#   'Blackstone / GSO Strategic Credit Fund, ',
#   'Blackstone GSO Long Short Credit Income Fund, ',
#   'Blackstone GSO Senior Floating Rate Term Fund, ',
#   'BrandywineGLOBAL Global Income Opportunities Fund , ',
#   'Brookfield Global Listed Infrastructure Income Fund, ',
#   'Brookfield Real Assets Income Fund Inc., ',
#   'CBRE Clarion Global Real Estate Income Fund, ',
#   'China Fund, Inc. (The), ',
#   'ClearBridge Energy Midstream Opportunity Fund Inc., ',
#   'ClearBridge MLP and Midstream Fund Inc., ',
#   'ClearBridge MLP and Midstream Total Return Fund In, ',
#   'Cohen & Steers Closed-End Opportunity Fund, Inc., ',
#   'Cohen & Steers Infrastructure Fund, Inc, ',
#   'Cohen & Steers Limited Duration Preferred and Income Fund, Inc, ',
#   'Cohen & Steers MLP Income and Energy Opportunity Fund, Inc., ',
#   'Cohen & Steers Quality Income Realty Fund Inc, ',
#   'Cohen & Steers REIT and Preferred and Income Fund,, ',
#   'Cohen & Steers Select Preferred and Income Fund, Inc., ',
#   'Cohen & Steers Total Return Realty Fund, Inc., ',
#   'Colonial Intermediate High Income Fund, ',
#   'Columbia Seligman Premium Technology Growth Fund, Inc, ',
#   'Cushing Energy Income Fund (The), ',
#   'Cushing MLP & Infrastructure Total Return Fund, ',
#   'Cushing Renaissance Fund (The), ',
#   'Delaware Investments Dividend & Income Fund, Inc., ',
#   'Dividend and Income Fund, ',
#   'DoubleLine Income Solutions Fund, ',
#   'DoubleLine Opportunistic Credit Fund, ',
#   'Dreyfus High Yield Strategies Fund, ',
#   'Dreyfus Municipal Bond Infrastructure Fund, Inc., ',
#   'Dreyfus Strategic Municipal Bond Fund, Inc., ',
#   'Duff & Phelps Global Utility Income Fund Inc., ',
#   'Duff & Phelps Select MLP and Midstream Energy Fund, ',
#   'Eagle Growth and Income Opportunities Fund, ',
#   'Eaton Vance Enhance Equity Income Fund, ',
#   'Eaton Vance Enhanced Equity Income Fund II, ',
#   'Eaton vance Floating-Rate Income Plus Fund, ',
#   'Eaton Vance Risk-Managed Diversified Equity Income Fund, ',
#   'Eaton Vance Senior Floating-Rate Fund, ',
#   'Eaton Vance Short Diversified Income Fund, ',
#   'Eaton Vance Tax Advantaged Dividend Income Fund, ',
#   'Eaton Vance Tax-Advantaged Global Dividend Income Fund, ',
#   'Eaton Vance Tax-Managed Buy-Write Income Fund, ',
#   'Eaton Vance Tax-Managed Buy-Write Strategy Fund, ',
#   'Eaton Vance Tax-Managed Diversified Equity Income Fund, ',
#   'Eaton Vance Tax-Managed Global Diversified Equity Income Fund, ',
#   'European Equity Fund, Inc. (The), ',
#   'Federated Premier Municipal Income Fund, ',
#   'Fiduciary/Claymore Energy Infrastructure Fund, ',
#   'First Trust Dynamic Europe Equity Income Fund, ',
#   'First Trust Energy Infrastructure Fund, ',
#   'First Trust High Income Long Short Fund, ',
#   'First Trust Intermediate Duration Preferred & Income Fund, ',
#   'First Trust MLP and Energy Income Fund, ',
#   'First Trust New Opportunities MLP & Energy Fund, ',
#   'First Trust Senior Floating Rate 2022 Target Term Fund, ',
#   'First Trust Senior Floating Rate Income Fund II, ',
#   'First Trust Specialty Finance and Financial Opportunities Fund, ',
#   'First Trust/Aberdeen Emerging Opportunity Fund, ',
#   'First Trust/Aberdeen Global Opportunity Income Fund, ',
#   'Flaherty & Crumrine Dynamic Preferred and Income Fund Inc., ',
#   'Flaherty & Crumrine Preferred Income Fund Incorporated, ',
#   'Flaherty & Crumrine Preferred Income Opportunity Fund Inc, ',
#   'Flaherty & Crumrine Preferred Securities Income Fund Inc, ',
#   'Flaherty & Crumrine Total Return Fund Inc, ',
#   'Gabelli Convertible and Income Securities Fund, Inc. (The), ',
#   'Goldman Sachs MLP Energy Renaissance Fund, ',
#   'Goldman Sachs MLP Income Opportunities Fund, ',
#   'Guggenheim Credit Allocation Fund, ',
#   'Guggenheim Enhanced Equity Income Fund, ',
#   'Guggenheim Strategic Opportunities Fund, ',
#   'High Income Securities Fund, ',
#   'Highland Floating Rate Opportunities Fund, ',
#   'Highland Global Allocation Fund, ',
#   'India Fund, Inc. (The), ',
#   'Insight Select Income Fund, ',
#   'Invesco Bond Fund, ',
#   'Invesco Credit Opportunities Fund, ',
#   'Invesco High Income 2023 Target Term Fund, ',
#   'Invesco High Income 2024 Target Term Fund, ',
#   'Ivy High Income Opportunities Fund, ',
#   'Japan Smaller Capitalization Fund Inc, ',
#   'John Hancock Financial Opportunities Fund, ',
#   'John Hancock Hedged Equity & Income Fund, ',
#   'John Hancock Pfd Income Fund II, ',
#   'John Hancock Preferred Income Fund, ',
#   'John Hancock Preferred Income Fund III, ',
#   'John Hancock Premium Dividend Fund, ',
#   'John Hancock Tax Advantaged Dividend Income Fund, ',
#   'John Hancock Tax-Advantaged Global Shareholder Yield Fund, ',
#   'Kayne Anderson Midstream Energy Fund, Inc, ',
#   'KKR Income Opportunities Fund, ',
#   'Korea Fund, Inc. (The), ',
#   'Lazard Global Total Return and Income Fund, ',
#   'Lazard World Dividend & Income Fund, Inc., ',
#   'Liberty All-Star Equity Fund, ',
#   'Liberty All-Star Growth Fund, Inc., ',
#   'LMP Capital and Income Fund Inc., ',
#   'Macquarie Global Infrastructure Total Return Fund Inc., ',
#   'Madison Covered Call & Equity Strategy Fund, ',
#   'Mexico Equity and Income Fund, Inc. (The), ',
#   'Mexico Fund, Inc. (The), ',
#   'Miller/Howard High Income Equity Fund, ',
#   'Morgan Stanley China A Share Fund Inc., ',
#   'Morgan Stanley Emerging Markets Debt Fund, Inc., ',
#   'Morgan Stanley Emerging Markets Domestic Debt Fund, Inc., ',
#   'Morgan Stanley India Investment Fund, Inc., ',
#   'MuniVest Fund, Inc., ',
#   'MuniYield Arizona Fund, Inc., ',
#   'New America High Income Fund, Inc. (The), ',
#   'New Germany Fund, Inc. (The), ',
#   'New Ireland Fund, Inc. (The), ',
#   'NexPoint Strategic Opportunities Fund, ',
#   'Nuveen All Cap Energy MLP Opportunities Fund, ',
#   'Nuveen AMT-Free Municipal Credit Income Fund, ',
#   'Nuveen AMT-Free Municipal Value Fund, ',
#   'Nuveen AMT-Free Quality Municipal Income Fund, ',
#   'Nuveen Virginia Quality Municipal Income Fund, ',
#   'Nuveenn Intermediate Duration Quality Municipal Term Fund, ',
#   'Nuven Mortgage Opportunity Term Fund 2, ',
#   'PGIM Global High Yield Fund, Inc., ',
#   'PGIM High Yield Bond Fund, Inc., ',
#   'PIMCO California Municipal Income Fund, ',
#   'Pimco California Municipal Income Fund II, ',
#   'PIMCO California Municipal Income Fund III, ',
#   'Pimco Corporate & Income Opportunity Fund, ',
#   'Pimco Corporate & Income Stategy Fund, ',
#   'PIMCO Dynamic Credit and Mortgage Income Fund, ',
#   'PIMCO Dynamic Income Fund, ',
#   'PIMCO Energy and Tactical Credit Opportunities Fund, ',
#   'Pimco Global Stocksplus & Income Fund, ',
#   'Pimco High Income Fund, ',
#   'Pimco Income Opportunity Fund, ',
#   'PIMCO Income Strategy Fund, ',
#   'PIMCO Income Strategy Fund II, ',
#   'PIMCO Municipal Income Fund, ',
#   'Pimco Municipal Income Fund II, ',
#   'PIMCO Municipal Income Fund III, ',
#   'PIMCO New York Municipal Income Fund, ',
#   'Pimco New York Municipal Income Fund II, ',
#   'PIMCO New York Municipal Income Fund III, ',
#   'PIMCO Strategic Income Fund, Inc., ',
#   'Principal Real Estate Income Fund, ',
#   'Priority Income Fund, Inc., ',
#   'RiverNorth Opportunistic Municipal Income Fund, Inc., ',
#   'RiverNorth Opportunities Fund, Inc., ',
#   'RiverNorth/DoubleLine Strategic Opportunity Fund, Inc., ',
#   'Salient Midstream & MLP Fund, ',
#   'Special Opportunities Fund Inc., ',
#   'Stone Harbor Emerging Markets Income Fund, ',
#   'Stone Harbor Emerging Markets Total Income Fund, ',
#   'Swiss Helvetia Fund, Inc. (The), ',
#   'Taiwan Fund, Inc. (The), ',
#   'TCW Strategic Income Fund, Inc., ',
#   'Tekla Healthcare Opportunies Fund, ',
#   'Tekla World Healthcare Fund, ',
#   'Templeton Dragon Fund, Inc., ',
#   'Templeton Emerging Markets Fund, ',
#   'Templeton Emerging Markets Income Fund, Inc., ',
#   'Templeton Global Income Fund, Inc., ',
#   'The Central and Eastern Europe Fund, Inc., ',
#   'The GDL Fund, ',
#   'The Vivaldi Opportunities Fund, ',
#   'THL Credit Senior Loan Fund, ',
#   'Tortoise Energy Independence Fund, Inc., ',
#   'Tortoise Essential Assets Income Term Fund, ',
#   'Tortoise Midstream Energy Fund, Inc., ',
#   'Tortoise Pipeline & Energy Fund, Inc., ',
#   'Tortoise Power and Energy Infrastructure Fund, Inc, ',
#   'USLIFE Income Fund, Inc., ',
#   'Virtus Global Dividend & Income Fund Inc., ',
#   'Virtus Global Multi-Sector Income Fund, ',
#   'Virtus Total Return Fund Inc., ',
#   'Voya Asia Pacific High Dividend Equity Income Fund, ',
#   'Voya Emerging Markets High Income Dividend Equity Fund, ',
#   'Voya Global Advantage and Premium Opportunity Fund, ',
#   'Voya Global Equity Dividend and Premium Opportunity Fund, ',
#   'Voya Infrastructure, Industrials and Materials Fund, ',
#   'Voya International High Dividend Equity Income Fund, ',
#   'Voya Natural Resources Equity Income Fund, ',
#   'Wells Fargo Global Dividend Opportunity Fund, ',
#   'Western Asset Bond Fund, ',
#   'Western Asset Corporate Loan Fund Inc, ',
#   'Western Asset Emerging Markets Debt Fund Inc, ',
#   'Western Asset Global Corporate Defined Opportunity Fund Inc., ',
#   'Western Asset Global High Income Fund Inc, ',
#   'Western Asset High Income Fund II Inc., ',
#   'Western Asset High Income Opportunity Fund, Inc., ',
#   'Western Asset High Yield Defined Opportunity Fund Inc., ',
#   'Western Asset Intermediate Muni Fund Inc, ',
#   'Western Asset Investment Grade Income Fund Inc., ',
#   'Western Asset Managed Municipals Fund, Inc., ',
#   'Western Asset Mortgage Defined Opportunity Fund Inc, ',
#   'Western Asset Municipal High Income Fund, Inc., ',
#   'Western Asset Municipal Partners Fund, Inc., ',
#   'Western Asset Variable Rate Strategic Fund Inc., '],
#  'Australia': ['Aberdeen Australia Equity Fund Inc, ',
#   'Sundance Energy Australia Limited, '],
#  'Equity': ['Aberdeen Australia Equity Fund Inc, ',
#   'Aberdeen Emerging Markets Equity Income Fund, Inc., ',
#   'Clough Global Equity Fund, ',
#   'Davis Select U.S. Equity ETF, ',
#   'Equity Bancshares, Inc., ',
#   'ETF Series Solutions Trust Vident Core US Equity ETF, ',
#   'ETF Series Solutions Trust Vident International Equity Fund, ',
#   'First Trust Developed International Equity Select ETF, ',
#   'First Trust Emerging Markets Equity Select ETF, ',
#   'First Trust International Equity Opportunities ETF, ',
#   'First Trust IPOX Europe Equity Opportunities ETF, ',
#   'First Trust Large Cap US Equity Select ETF, ',
#   'First Trust Mid Cap US Equity Select ETF, ',
#   'First Trust Small Cap US Equity Select ETF, ',
#   'First Trust US Equity Dividend Select ETF, ',
#   'Invesco High Yield Equity Dividend Achievers ETF, ',
#   'Invesco KBW Premium Yield Equity REIT ETF, ',
#   'WisdomTree Germany Hedged Equity Fund, ',
#   'WisdomTree Japan Hedged SmallCap Equity Fund, ',
#   'Aberdeen Japan Equity Fund, Inc. , ',
#   'Adams Diversified Equity Fund, Inc., ',
#   'AllianzGI Equity & Convertible Income Fund, ',
#   'American Equity Investment Life Holding Company, ',
#   'Blackrock Enhanced Equity Dividend Trust, ',
#   'Crestwood Equity Partners LP, ',
#   'Eaton Vance Enhance Equity Income Fund, ',
#   'Eaton Vance Enhanced Equity Income Fund II, ',
#   'Eaton Vance Risk-Managed Diversified Equity Income Fund, ',
#   'Eaton Vance Tax-Managed Diversified Equity Income Fund, ',
#   'Eaton Vance Tax-Managed Global Diversified Equity Income Fund, ',
#   'Equity Commonwealth, ',
#   'Equity Lifestyle Properties, Inc., ',
#   'Equity Residential, ',
#   'European Equity Fund, Inc. (The), ',
#   'First Trust Dynamic Europe Equity Income Fund, ',
#   'Gabelli Equity Trust, Inc. (The), ',
#   'Guggenheim Enhanced Equity Income Fund, ',
#   'John Hancock Hedged Equity & Income Fund, ',
#   'Liberty All-Star Equity Fund, ',
#   'Madison Covered Call & Equity Strategy Fund, ',
#   'Mexico Equity and Income Fund, Inc. (The), ',
#   'Miller/Howard High Income Equity Fund, ',
#   'Nuveen Core Equity Alpha Fund, ',
#   'Voya Asia Pacific High Dividend Equity Income Fund, ',
#   'Voya Emerging Markets High Income Dividend Equity Fund, ',
#   'Voya Global Equity Dividend and Premium Opportunity Fund, ',
#   'Voya International High Dividend Equity Income Fund, ',
#   'Voya Natural Resources Equity Income Fund, '],
#  'Emerging': ['Aberdeen Emerging Markets Equity Income Fund, Inc., ',
#   'First Trust Emerging Markets AlphaDEX Fund, ',
#   'First Trust Emerging Markets Equity Select ETF, ',
#   'First Trust Emerging Markets Local Currency Bond ETF, ',
#   'First Trust Emerging Markets Small Cap AlphaDEX Fund, ',
#   'First Trust RiverFront Dynamic Emerging Markets ETF, ',
#   'Invesco BLDRS Emerging Markets 50 ADR Index Fund, ',
#   'Invesco DWA Emerging Markets Momentum ETF, ',
#   'Invesco RAFI Strategic Emerging Markets ETF, ',
#   'iShares J.P. Morgan USD Emerging Markets Bond ETF, ',
#   'iShares MSCI Emerging Markets Asia ETF, ',
#   'iShares MSCI Emerging Markets ex China ETF, ',
#   'iShares S&P Emerging Markets Infrastructure Index Fund, ',
#   'Vanguard Emerging Markets Government Bond ETF, ',
#   'VictoryShares Emerging Market High Div Volatility Wtd ETF, ',
#   'VictoryShares Emerging Market Volatility Wtd ETF, ',
#   'WisdomTree Emerging Markets Consumer Growth Fund, ',
#   'WisdomTree Emerging Markets Corporate Bond Fund, ',
#   'WisdomTree Emerging Markets Quality Dividend Growth Fund, ',
#   'First Trust/Aberdeen Emerging Opportunity Fund, ',
#   'Morgan Stanley Emerging Markets Debt Fund, Inc., ',
#   'Morgan Stanley Emerging Markets Domestic Debt Fund, Inc., ',
#   'Nuveen Emerging Markets Debt 2022 Target Term Fund, ',
#   'Stone Harbor Emerging Markets Income Fund, ',
#   'Stone Harbor Emerging Markets Total Income Fund, ',
#   'Templeton Emerging Markets Fund, ',
#   'Templeton Emerging Markets Income Fund, Inc., ',
#   'Voya Emerging Markets High Income Dividend Equity Fund, ',
#   'Western Asset Emerging Markets Debt Fund Inc, '],
#  'Global': ['Aberdeen Global Income Fund, Inc., ',
#   'Clough Global Dividend and Income Fund, ',
#   'Clough Global Equity Fund, ',
#   'Clough Global Opportunities Fund, ',
#   'GAMCO Global Gold, Natural Reources & Income Trust , ',
#   'The Gabelli Global Utility and Income Trust, ',
#   'BioHiTech Global, Inc., ',
#   'Calamos Global Dynamic Income Fund, ',
#   'Calamos Global Total Return Fund, ',
#   'Cboe Global Markets, Inc., ',
#   'CDK Global, Inc., ',
#   'CUI Global, Inc., ',
#   'DMC Global Inc., ',
#   'Echo Global Logistics, Inc., ',
#   'Exchange Traded Concepts Trust ROBO Global Robotics and Automa, ',
#   'First Trust Global Tactical Commodity Strategy Fund, ',
#   'First Trust Indxx Global Agriculture ETF, ',
#   'First Trust Indxx Global Natural Resources Income ETF, ',
#   'First Trust NASDAQ Global Auto Index Fund, ',
#   'FlexShares STOXX Global ESG Impact Index Fund, ',
#   'Fuling Global Inc., ',
#   'Global Blood Therapeutics, Inc., ',
#   'Global Eagle Entertainment Inc., ',
#   'Global Indemnity Limited, ',
#   'Global Self Storage, Inc., ',
#   'Global Water Resources, Inc., ',
#   'Global X Autonomous & Electric Vehicles ETF, ',
#   'Global X Cloud Computing ETF, ',
#   'Global X Conscious Companies ETF, ',
#   'Global X DAX Germany ETF, ',
#   'Global X E-commerce ETF, ',
#   'Global X FinTech ETF, ',
#   'Global X Future Analytics Tech ETF, ',
#   'Global X Genomics & Biotechnology ETF, ',
#   'Global X Health & Wellness Thematic ETF, ',
#   'Global X Internet of Things ETF, ',
#   'Global X Longevity Thematic ETF, ',
#   'Global X Millennials Thematic ETF, ',
#   'Global X MSCI China Communication Services ETF, ',
#   'Global X MSCI SuperDividend EAFE ETF, ',
#   'Global X NASDAQ-100 Covered Call ETF, ',
#   'Global X Robotics & Artificial Intelligence ETF, ',
#   'Global X S&P 500 Catholic Values ETF, ',
#   'Global X Social Media ETF, ',
#   'Global X SuperDividend Alternatives ETF, ',
#   'Global X SuperDividend REIT ETF, ',
#   'Global X YieldCo & Renewable Energy Income ETF, ',
#   'Hudson Global, Inc., ',
#   'Invesco Global Water ETF, ',
#   'iShares FTSE EPRA/NAREIT Global Real Estate ex-U.S. Index Fund, ',
#   'iShares Global Green Bond ETF, ',
#   'iShares Global Infrastructure ETF, ',
#   'iShares MSCI Global Gold Miners ETF, ',
#   'iShares MSCI Global Impact ETF, ',
#   'iShares S&P Global Clean Energy Index Fund, ',
#   'iShares S&P Global Timber & Forestry Index Fund, ',
#   'j2 Global, Inc., ',
#   'Legg Mason Global Infrastructure ETF, ',
#   'Liberty Global plc, ',
#   'NV5 Global, Inc., ',
#   'Oxford Immunotec Global PLC, ',
#   'PRGX Global, Inc., ',
#   'Sino-Global Shipping America, Ltd., ',
#   'SMART Global Holdings, Inc., ',
#   'U.S. Global Investors, Inc., ',
#   'Vanguard Global ex-U.S. Real Estate ETF, ',
#   'Aberdeen Global Dynamic Dividend Fund, ',
#   'Aberdeen Global Premier Properties Fund, ',
#   'Adtalem Global Education Inc., ',
#   'Apollo Global Management, LLC, ',
#   'Ashland Global Holdings Inc., ',
#   'Azure Power Global Limited, ',
#   'Babson Global Short Duration High Yield Fund, ',
#   'Berry Global Group, Inc., ',
#   'BlackRock 2022 Global Income Opportunity Trust, ',
#   'Blackrock Global, ',
#   'BrandywineGLOBAL Global Income Opportunities Fund , ',
#   'Brookfield Global Listed Infrastructure Income Fund, ',
#   'CBRE Clarion Global Real Estate Income Fund, ',
#   'Cohen & Steers Global Income Builder, Inc., ',
#   'Delaware Enhanced Global Dividend, ',
#   'Dine Brands Global, Inc., ',
#   'Duff & Phelps Global Utility Income Fund Inc., ',
#   'Eaton Vance Tax-Advantage Global Dividend Opp, ',
#   'Eaton Vance Tax-Advantaged Global Dividend Income Fund, ',
#   'Eaton Vance Tax-Managed Global Diversified Equity Income Fund, ',
#   'First Trust/Aberdeen Global Opportunity Income Fund, ',
#   'Gabelli Global Small and Mid Cap Value Trust (The), ',
#   'Global Brass and Copper Holdings, Inc., ',
#   'Global Cord Blood Corporation, ',
#   'Global Medical REIT Inc., ',
#   'Global Net Lease, Inc., ',
#  'Blackbaud': ['Blackbaud, Inc., '],
#  'BlackLine': ['BlackLine, Inc., '],
#  'BlackRock': ['BlackRock Capital Investment Corporation, ',
#   'BlackRock TCP Capital Corp., ',
#   'BlackRock 2022 Global Income Opportunity Trust, ',
#   'BlackRock California Municipal Income Trust, ',
#   'BlackRock Credit Allocation Income Trust, ',
#   'BlackRock Energy and Resources Trust, ',
#   'BlackRock Income Investment Quality Trust, ',
#   'BlackRock Income Trust Inc. (The), ',
#   'BlackRock Investment Quality Municipal Trust Inc. (The), ',
#   'BlackRock Long-Term Municipal Advantage Trust, ',
#   'BlackRock Maryland Municipal Bond Trust, ',
#   'BlackRock Massachusetts Tax-Exempt Trust, ',
#   'BlackRock Multi-Sector Income Trust, ',
#   'BlackRock Municipal Income Investment Trust, ',
#   'BlackRock Municipal Income Trust, ',
#   'BlackRock Municipal Income Trust II, ',
#   'BlackRock Municipal Target Term Trust Inc. (The), ',
#   'BlackRock New York Investment Quality Municipal Trust Inc. (Th, ',
#   'BlackRock New York Municipal Income Trust II, ',
#   'BlackRock Resources, ',
#   'BlackRock Science and Technology Trust, ',
#   'BlackRock Strategic Municipal Trust Inc. (The), ',
#   'BlackRock Utility, Infrastructure & Power Opportun, ',
#   'BlackRock Virginia Municipal Bond Trust, ',
#   'BlackRock, Inc., '],
#  'TCP': ['BlackRock TCP Capital Corp., '],
#  'Blink': ['Blink Charging Co., '],
#  'Charging': ['Blink Charging Co., '],
#  'Bloomin': ['Bloomin&#39; Brands, Inc., '],
#  'Blucora': ['Blucora, Inc., '],
#  'Blue': ['Blue Bird Corporation, ',
#   'Blue Apron Holdings, Inc., ',
#   'Blue Capital Reinsurance Holdings Ltd., '],
#  'Bird': ['Blue Bird Corporation, '],
#  'bluebird': ['bluebird bio, Inc., '],
#  'bio': ['bluebird bio, Inc., ', 'IVERIC bio, Inc., '],
#  'Blueknight': ['Blueknight Energy Partners L.P., L.L.C., '],
#  'Blueprint': ['Blueprint Medicines Corporation, '],
#  'Medicines': ['Blueprint Medicines Corporation, ',
#   'Homology Medicines, Inc., ',
#   'The Medicines Company, '],
#  'BlueStar': ['BlueStar Israel Technology ETF, '],
#  'Israel': ['BlueStar Israel Technology ETF, ',
#   'Cellcom Israel, Ltd., ',
#   'Israel Chemicals Shs, '],
#  'BMC': ['BMC Stock Holdings, Inc., '],
#  'Stock': ['BMC Stock Holdings, Inc., ',
#   'Fidelity Nasdaq Composite Index Tracking Stock, ',
#   'iShares Core MSCI Total International Stock ETF, ',
#   'Stock Yards Bancorp, Inc., ',
#   'Vanguard Total International Stock ETF, '],
#  'Boingo': ['Boingo Wireless, Inc., '],
#  'BOK': ['BOK Financial Corporation, '],
#  'Bonso': ['Bonso Electronics International, Inc., '],
#  'Booking': ['Booking Holdings Inc., '],
#  'Borqs': ['Borqs Technologies, Inc. , '],
#  'Boston': ['Boston Omaha Corporation, ',
#   'Boston Private Financial Holdings, Inc., ',
#   'Boston Beer Company, Inc. (The), ',
#   'Boston Properties, Inc., ',
#   'Boston Scientific Corporation, '],
#  'Omaha': ['Boston Omaha Corporation, '],
#  'Private': ['Boston Private Financial Holdings, Inc., '],
#  'Bottomline': ['Bottomline Technologies, Inc., '],
#  'Boxlight': ['Boxlight Corporation, '],
#  'Boxwood': ['Boxwood Merger Corp., '],
#  'Brainstorm': ['Brainstorm Cell Therapeutics Inc., '],
#  'Cell': ['Brainstorm Cell Therapeutics Inc., ', 'Gamida Cell Ltd., '],
#  'Brainsway': ['Brainsway Ltd., '],
#  'Brandes': ['Brandes Investment Trust, '],
#  'Bridge': ['Bridge Bancorp, Inc., ',
#   'Manhattan Bridge Capital, Inc, ',
#   'Thunder Bridge Acquisition, Ltd., '],
#  'Bridgeline': ['Bridgeline Digital, Inc., '],
#  'Bridgewater': ['Bridgewater Bancshares, Inc., '],
#  'Bridgford': ['Bridgford Foods Corporation, '],
#  'Brightcove': ['Brightcove Inc., '],
#  'Brighthouse': ['Brighthouse Financial, Inc., '],
#  'Broadcom': ['Broadcom Inc., '],
#  'BroadVision': ['BroadVision, Inc., '],
#  'Broadway': ['Broadway Financial Corporation, '],
#  'Broadwind': ['Broadwind Energy, Inc., '],
#  'Brookfield': ['Brookfield Property Partners L.P., ',
#   'Brookfield Property REIT Inc., ',
#   'Brookfield Asset Management Inc, ',
#   'Brookfield Business Partners L.P., ',
#   'Brookfield DTLA Inc., ',
#   'Brookfield Global Listed Infrastructure Income Fund, ',
#   'Brookfield Infrastructure Partners LP, ',
#   'Brookfield Real Assets Income Fund Inc., ',
#   'Brookfield Renewable Partners L.P., ',
#   'Center Coast Brookfield MLP & Energy Infrastructur, '],
#  'Brookline': ['Brookline Bancorp, Inc., '],
#  'Brooks': ['Brooks Automation, Inc., '],
#  'Automation': ['Brooks Automation, Inc., ',
#   'Hollysys Automation Technologies, Ltd., ',
#   'Rockwell Automation, Inc., '],
#  'BRP': ['BRP Inc., '],
#  'Bruker': ['Bruker Corporation, '],
#  'Bryn': ['Bryn Mawr Bank Corporation, '],
#  'Mawr': ['Bryn Mawr Bank Corporation, '],
#  'BSQUARE': ['BSQUARE Corporation, '],
#  'Builders': ['Builders FirstSource, Inc., '],
#  'FirstSource': ['Builders FirstSource, Inc., '],
#  'Robinson': ['C.H. Robinson Worldwide, Inc., '],
#  'Cabot': ['Cabot Microelectronics Corporation, ',
#   'Cabot Corporation, ',
#   'Cabot Oil & Gas Corporation, '],
#  'Microelectronics': ['Cabot Microelectronics Corporation, ',
#   'United Microelectronics Corporation, '],
#  'Cadence': ['Cadence Design Systems, Inc., ', 'Cadence Bancorporation, '],
#  'Design': ['Cadence Design Systems, Inc., '],
#  'Cadiz': ['Cadiz, Inc., '],
#  'Caesars': ['Caesars Entertainment Corporation, '],
#  'Entertainment': ['Caesars Entertainment Corporation, ',
#   'Chicken Soup for the Soul Entertainment, Inc., ',
#   'Dave & Buster&#39;s Entertainment, Inc., ',
#   'Dolphin Entertainment, Inc., ',
#   'Global Eagle Entertainment Inc., ',
#   'Golden Entertainment, Inc., ',
#   'Inspired Entertainment, Inc., ',
#   'iPic Entertainment Inc., ',
#   'Melco Resorts & Entertainment Limited, ',
#   'Trans World Entertainment Corp., ',
#   'AMC Entertainment Holdings, Inc., ',
#   'Lions Gate Entertainment Corporation, ',
#   'Live Nation Entertainment, Inc., ',
#   'SeaWorld Entertainment, Inc., ',
#   'Six Flags Entertainment Corporation New, ',
#   'Tencent Music Entertainment Group, ',
#   'World Wrestling Entertainment, Inc., '],
#  'Caesarstone': ['Caesarstone Ltd., '],
#  'Caladrius': ['Caladrius Biosciences, Inc., '],
#  'Calamos': ['Calamos Convertible and High Income Fund, ',
#   'Calamos Convertible Opportunities and Income Fund, ',
#   'Calamos Dynamic Convertible & Income Fund, ',
#   'Calamos Global Dynamic Income Fund, ',
#   'Calamos Global Total Return Fund, ',
#   'Calamos Strategic Total Return Fund, '],
#  'Convertible': ['Calamos Convertible and High Income Fund, ',
#   'Calamos Convertible Opportunities and Income Fund, ',
#   'Calamos Dynamic Convertible & Income Fund, ',
#   'First Trust SSI Strategic Convertible Securities ETF, ',
#   'Advent Claymore Convertible Securities and Income Fund, ',
#   'AllianzGI Convertible & Income 2024 Target Term Fund, ',
#   'AllianzGI Convertible & Income Fund, ',
#   'AllianzGI Convertible & Income Fund II, ',
#   'AllianzGI Diversified Income & Convertible Fund, ',
#   'AllianzGI Equity & Convertible Income Fund, ',
#   'Gabelli Convertible and Income Securities Fund, Inc. (The), '],
#  'Dynamic': ['Calamos Dynamic Convertible & Income Fund, ',
#   'Calamos Global Dynamic Income Fund, ',
#   'First Trust Dorsey Wright Dynamic Focus 5 ETF, ',
#   'First Trust RiverFront Dynamic Asia Pacific ETF, ',
#   'First Trust RiverFront Dynamic Developed International ETF, ',
#   'First Trust RiverFront Dynamic Emerging Markets ETF, ',
#   'First Trust RiverFront Dynamic Europe ETF, ',
#   'Nuveen NASDAQ 100 Dynamic Overwrite Fund, ',
#   'Aberdeen Global Dynamic Dividend Fund, ',
#   'Aberdeen Total Dynamic Dividend Fund, ',
#   'Ares Dynamic Credit Allocation Fund, Inc., ',
#   'First Trust Dynamic Europe Equity Income Fund, ',
#   'Flaherty & Crumrine Dynamic Preferred and Income Fund Inc., ',
#   'Nuveen Dow 30SM Dynamic Overwrite Fund, ',
#   'Nuveen S&P 500 Dynamic Overwrite Fund, ',
#   'PIMCO Dynamic Credit and Mortgage Income Fund, ',
#   'PIMCO Dynamic Income Fund, '],
#  'CalAmp': ['CalAmp Corp., '],
#  'Calavo': ['Calavo Growers, Inc., '],
#  'Growers': ['Calavo Growers, Inc., '],
#  'Calithera': ['Calithera Biosciences, Inc., '],
#  'Cal': ['Cal-Maine Foods, Inc., '],
#  'Maine': ['Cal-Maine Foods, Inc., '],
#  'Calumet': ['Calumet Specialty Products Partners, L.P., '],
#  'Specialty': ['Calumet Specialty Products Partners, L.P., ',
#   'Oaktree Specialty Lending Corporation, ',
#   'Bain Capital Specialty Finance, Inc., ',
#   'First Trust Specialty Finance and Financial Opportunities Fund, ',
#   'TPG Specialty Lending, Inc., '],
#  'Calvert': ['Calvert Management Series, '],
#  'Series': ['Calvert Management Series, ',
#   'ETF Series Solutions Trust Vident Core U.S. Bond Strategy Fund, ',
#   'ETF Series Solutions Trust Vident Core US Equity ETF, ',
#   'ETF Series Solutions Trust Vident International Equity Fund, ',
#   'Invesco QQQ Trust, Series 1, ',
#   'CABCO Series 2004-101 Trust, ',
#   'MS Structured Asset Corp Saturns GE Cap Corp Series 2002-14, '],
#  'Calyxt': ['Calyxt, Inc., '],
#  'Cambridge': ['Cambridge Bancorp, '],
#  'Camden': ['Camden National Corporation, ', 'Camden Property Trust, '],
#  'Camtek': ['Camtek Ltd., '],
#  'Canadian': ['Canadian Solar Inc., ',
#   'Canadian Imperial Bank of Commerce, ',
#   'Canadian National Railway Company, ',
#   'Canadian Natural Resources Limited, ',
#   'Canadian Pacific Railway Limited, '],
#  'Solar': ['Canadian Solar Inc., ',
#   'Envision Solar International, Inc., ',
#   'First Solar, Inc., ',
#   'Sky Solar Holdings, Ltd., ',
#   'Solar Capital Ltd., ',
#   'Solar Senior Capital Ltd., ',
#   'Vivint Solar, Inc., '],
#  'Cancer': ['Cancer Genetics, Inc., ', 'Loncar Cancer Immunotherapy ETF, '],
#  'Canterbury': ['Canterbury Park Holding Corporation, '],
#  'Product': ['Capital Product Partners L.P., '],
#  'Capitala': ['Capitala Finance Corp., '],
#  'Capitol': ['Capitol Federal Financial, Inc., ',
#   'Capitol Investment Corp. IV, '],
#  'Capricor': ['Capricor Therapeutics, Inc., '],
#  'CapStar': ['CapStar Financial Holdings, Inc., '],
#  'Capstone': ['Capstone Turbine Corporation, '],
#  'Turbine': ['Capstone Turbine Corporation, ', 'Digital Turbine, Inc., '],
#  'Cara': ['Cara Therapeutics, Inc., '],
#  'Carbon': ['Carbon Black, Inc., '],
#  'Carbonite': ['Carbonite, Inc., '],
#  'Cardiovascular': ['Cardiovascular Systems, Inc., '],
#  'Cardlytics': ['Cardlytics, Inc., '],
#  'Cardtronics': ['Cardtronics plc, '],
#  'CareDx': ['CareDx, Inc., '],
#  'Career': ['Career Education Corporation, '],
#  'CareTrust': ['CareTrust REIT, Inc., '],
#  'CarGurus': ['CarGurus, Inc., '],
#  'BancShares': ['Carolina Trust BancShares, Inc., ',
#   'First Citizens BancShares, Inc., ',
#   'Home BancShares, Inc., '],
#  'Carrizo': ['Carrizo Oil & Gas, Inc., '],
#  'Carrols': ['Carrols Restaurant Group, Inc., '],
#  'Restaurant': ['Carrols Restaurant Group, Inc., ',
#   'Del Frisco&#39;s Restaurant Group, Inc., ',
#   'Diversified Restaurant Holdings, Inc., ',
#   'Fiesta Restaurant Group, Inc., ',
#   'Rave Restaurant Group, Inc., ',
#   'Restaurant Brands International Inc., '],
#  'Carter': ['Carter Bank & Trust, ', 'Carter&#39;s, Inc., '],
#  'Carver': ['Carver Bancorp, Inc., '],
#  'CAS': ['CAS Medical Systems, Inc., '],
#  'Casa': ['Casa Systems, Inc., '],
#  'Casella': ['Casella Waste Systems, Inc., '],
#  'Waste': ['Casella Waste Systems, Inc., ',
#   'Waste Connections, Inc., ',
#   'Waste Management, Inc., '],
#  'Caseys': ['Caseys General Stores, Inc., '],
#  'CASI': ['CASI Pharmaceuticals, Inc., '],
#  'Cass': ['Cass Information Systems, Inc, '],
#  'Cassava': ['Cassava Sciences, Inc., '],
#  'Castor': ['Castor Maritime Inc., '],
#  'Maritime': ['Castor Maritime Inc., ',
#   'Globus Maritime Limited, ',
#   'Hunter Maritime Acquisition Corp., ',
#   'Navios Maritime Containers L.P., ',
#   'Seanergy Maritime Holdings Corp, ',
#   'Navios Maritime Acquisition Corporation, ',
#   'Navios Maritime Holdings Inc., ',
#   'Navios Maritime Partners LP, '],
#  'Catabasis': ['Catabasis Pharmaceuticals, Inc., '],
#  'Catalyst': ['Catalyst Biosciences, Inc. , ',
#   'Catalyst Pharmaceuticals, Inc., '],
#  'Catasys': ['Catasys, Inc., '],
#  'Cathay': ['Cathay General Bancorp, '],
#  'Causeway': ['Causeway ETMF Trust, '],
#  'ETMF': ['Causeway ETMF Trust, '],
#  'Cavco': ['Cavco Industries, Inc., '],
#  'CB': ['CB Financial Services, Inc., '],
#  'CBAK': ['CBAK Energy Technology, Inc., '],
#  'CBM': ['CBM Bancorp, Inc., '],
#  'Cboe': ['Cboe Global Markets, Inc., '],
#  'CBTX': ['CBTX, Inc., '],
#  'CDK': ['CDK Global, Inc., '],
#  'CDW': ['CDW Corporation, '],
#  'CECO': ['CECO Environmental Corp., '],
#  'Celcuity': ['Celcuity Inc., '],
#  'Celgene': ['Celgene Corporation, '],
#  'Celldex': ['Celldex Therapeutics, Inc., '],
#  'Cellect': ['Cellect Biotechnology Ltd., '],
#  'Biotechnology': ['Cellect Biotechnology Ltd., ',
#   'Global X Genomics & Biotechnology ETF, ',
#   'iShares Nasdaq Biotechnology Index Fund, ',
#   'PDS Biotechnology Corporation, ',
#   'ProShares Ultra Nasdaq Biotechnology, ',
#   'Proshares UltraPro Nasdaq Biotechnology, ',
#   'ProShares UltraPro Short NASDAQ Biotechnology, ',
#   'ProShares UltraShort Nasdaq Biotechnology, ',
#   'Puma Biotechnology Inc, ',
#   'Unity Biotechnology, Inc., '],
#  'Cellectar': ['Cellectar Biosciences, Inc., '],
#  'Cellectis': ['Cellectis S.A., '],
#  'Cellular': ['Cellular Biomedicine Group, Inc., ',
#   'Intra-Cellular Therapies Inc., ',
#   'Millicom International Cellular S.A., ',
#   'United States Cellular Corporation, '],
#  'Biomedicine': ['Cellular Biomedicine Group, Inc., '],
#  'Celsion': ['Celsion Corporation, '],
#  'Celsius': ['Celsius Holdings, Inc., '],
#  'Celyad': ['Celyad SA, '],
#  'Cemtrex': ['Cemtrex Inc., '],
#  'Centennial': ['Centennial Resource Development, Inc., '],
#  'Development': ['Centennial Resource Development, Inc., ',
#   'Educational Development Corporation, '],
#  'CenterState': ['CenterState Bank Corporation, '],
#  'European': ['Central European Media Enterprises Ltd., ',
#   'Coca-Cola European Partners plc, ',
#   'European Equity Fund, Inc. (The), ',
#   'North European Oil Royality Trust, '],
#  'Media': ['Central European Media Enterprises Ltd., ',
#   'Cumulus Media Inc., ',
#   'DHX Media Ltd., ',
#   'Global X Social Media ETF, ',
#   'Hemisphere Media Group, Inc., ',
#   'Integrated Media Technology Limited, ',
#   'Liberty Media Corporation, ',
#   'Liquid Media Group Ltd., ',
#   'LiveXLive Media, Inc., ',
#   'Modern Media Acquisition Corp., ',
#   'Nexstar Media Group, Inc., ',
#   'Salem Media Group, Inc., ',
#   'Gabelli Multi-Media Trust Inc. (The), ',
#   'New Media Investment Group Inc., ',
#   'OUTFRONT Media Inc., ',
#   'Phoenix New Media Limited, ',
#   'Townsquare Media, Inc., ',
#   'Tribune Media Company, '],
#  'Garden': ['Central Garden & Pet Company, ',
#   'The Madison Square Garden Company, '],
#  'Pet': ['Central Garden & Pet Company, '],
#  'Valley': ['Central Valley Community Bancorp, ',
#   'Codorus Valley Bancorp, Inc, ',
#   'Oak Valley Bancorp (CA), ',
#   'Ohio Valley Banc Corp., ',
#   'Valley National Bancorp, ',
#   'Willamette Valley Vineyards, Inc., ',
#   'Tennessee Valley Authority, '],
#  'Community': ['Central Valley Community Bancorp, ',
#   'Citizens Community Bancorp, Inc., ',
#   'Community Bankers Trust Corporation., ',
#   'Community First Bancshares, Inc., ',
#   'Community Trust Bancorp, Inc., ',
#   'Community West Bancshares, ',
#   'Dime Community Bancshares, Inc., ',
#   'First Community Bankshares, Inc., ',
#   'First Community Corporation, ',
#   'First Trust NASDAQ ABA Community Bank Index Fund, ',
#   'PDL Community Bancorp, ',
#   'The Community Financial Corporation, ',
#   'United Community Banks, Inc., ',
#   'United Community Financial Corp., ',
#   'Community Bank System, Inc., ',
#   'Community Health Systems, Inc., ',
#   'Community Healthcare Trust Incorporated, ',
#   'New York Community Bancorp, Inc., '],
#  'Centric': ['Centric Brands Inc., '],
#  'Aluminum': ['Century Aluminum Company, ',
#   'Kaiser Aluminum Corporation, ',
#   'Aluminum Corporation of China Limited, ',
#   'Reliance Steel & Aluminum Co., '],
#  'Ceragon': ['Ceragon Networks Ltd., '],
#  'Cerecor': ['Cerecor Inc., '],
#  'Cerner': ['Cerner Corporation, '],
#  ...}

# %%
i = 0
t = time.time()
def find_comp(string, words_dict = words_dict.copy(), lower = True,):
    ''' Find companies
    '''
    #====================================================
    string = ' %s '%string.lower()
        
    def my_label(string, str_lst):
        for s in str_lst:
            string = re.sub(r'(?<=\W)%s(?=\W)'%s.lower(), ' {%s} '%s.upper(), string )
        return string
    
    str_lst  = []
    comp_lst = []
    
    for k in words_dict.keys():
        
        comp = words_dict[k]
        
        if lower:
            k = k.lower()
            
            if  string != my_label(string, str_lst = [k] ):
                str_lst  += [k]
                
                comp_lst += comp
            
        else:
            if  string != my_label(string, str_lst = [k] ):
                str_lst  += [k]
                
                comp_lst += comp
                
    global i
    i += 1
    T = time.time() - t
    v = T/i
    Tt = data['text'].shape[0] * v
    
    if i % 10 == 0:
        print('% secs elapsed,'%T, '%s sec(s) left,'%(Tt - T), 'total %s sec(s)'%Tt )
    
    if len(str_lst) > 0:
        return my_label(string, str_lst = {*str_lst}), ''.join( list( {*comp_lst} ) )
    
    else:
        return np.nan, np.nan

# %% [markdown]
# res = data['text'].apply(lambda x: pd.Series( find_comp(x) ) )
